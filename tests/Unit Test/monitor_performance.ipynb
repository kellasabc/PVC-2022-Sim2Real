# %%
import os
import sys
sys.path.append("../..")
sys.path.append("../../,,")
from scripts.pix2pix_sim2choice80 import pix2pix
current_device = 'cuda:0'
json_file_name = 'train_valid_test.json'
json_folder = '../../src/config/train_valid_test'
json_path = os.path.join(json_folder, json_file_name)
log_file = "../../result/log/train_valid_test"
saved_model_file = "../../result/model"
batch_size = 24
import torch
torch.cuda.empty_cache()
pix2pix_model = pix2pix(current_device, batch_size, json_path, log_file,saved_model_file,\
                num_workers=None, lr=2e-4, beta=(0.5, 0.999), ori_size=(256,452))
pix2pix_model.train(epochs=50)
# Out:
# Availble devic of this machine is ---->  cuda:0
# ******************************
# train phase
# ******************************
#
# 2022-08-05 08:15:10.193692 Epoch 1, Generator loss 24.758670806884766, Discriminator loss 0.691242516040802
# ******************************
#  validation of epoch 1
# ******************************
#
# 2022-08-05 08:15:11.128428 Epoch 1, Generator loss 23.7567138671875, Discriminator loss 0.688670814037323
# the model is saved
# 2022-08-05 08:16:33.928341 Epoch 10, Generator loss 12.86483097076416, Discriminator loss 0.6538559198379517
# ******************************
#  validation of epoch 10
# ******************************
#
# 2022-08-05 08:16:34.354999 Epoch 10, Generator loss 13.771727561950684, Discriminator loss 0.643475353717804
# the model is saved
# 2022-08-05 08:18:05.297734 Epoch 20, Generator loss 6.522812843322754, Discriminator loss 0.6403889060020447
# ******************************
#  validation of epoch 20
# ******************************
#
# 2022-08-05 08:18:05.714040 Epoch 20, Generator loss 8.15909481048584, Discriminator loss 0.6310409903526306
# the model is saved
# 2022-08-05 08:19:37.944692 Epoch 30, Generator loss 6.0610270500183105, Discriminator loss 0.6194741129875183
# ******************************
#  validation of epoch 30
# ******************************
#
# 2022-08-05 08:19:38.369206 Epoch 30, Generator loss 8.797520637512207, Discriminator loss 0.529757559299469
# 2022-08-05 08:21:08.028780 Epoch 40, Generator loss 5.687618255615234, Discriminator loss 0.6080297231674194
# ******************************
#  validation of epoch 40
# ******************************
#
# 2022-08-05 08:21:08.440311 Epoch 40, Generator loss 8.095389366149902, Discriminator loss 0.5794706344604492
# the model is saved
# 2022-08-05 08:22:39.533832 Epoch 50, Generator loss 5.486288070678711, Discriminator loss 0.5531264543533325
# ******************************
#  validation of epoch 50
# ******************************
#
# 2022-08-05 08:22:39.993199 Epoch 50, Generator loss 7.93574333190918, Discriminator loss 0.6802379488945007
# the model is saved
